# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

file_path = r"/content/drive/MyDrive/observations.csv"
data = pd.read_csv(file_path)
data
# Out:
#              DATE                               PATIENT  \
# 0      2008-03-11  71949668-1c2e-43ae-ab0a-64654608defb
# 1      2008-03-11  71949668-1c2e-43ae-ab0a-64654608defb
# 2      2008-03-11  71949668-1c2e-43ae-ab0a-64654608defb
# 3      2008-03-11  71949668-1c2e-43ae-ab0a-64654608defb
# 4      2008-03-11  71949668-1c2e-43ae-ab0a-64654608defb
# ...           ...                                   ...
# 79669  2017-07-10  8b9de29c-34c9-405f-840c-71b5210cf9e1
# 79670  2017-07-10  8b9de29c-34c9-405f-840c-71b5210cf9e1
# 79671  2017-07-10  8b9de29c-34c9-405f-840c-71b5210cf9e1
# 79672  2017-10-31  8b9de29c-34c9-405f-840c-71b5210cf9e1
# 79673  2017-10-31  8b9de29c-34c9-405f-840c-71b5210cf9e1
#
#                                   ENCOUNTER       CODE  \
# 0      5114a5b4-64b8-47b2-82a6-0ce24aae0943     8302-2
# 1      5114a5b4-64b8-47b2-82a6-0ce24aae0943    29463-7
# 2      5114a5b4-64b8-47b2-82a6-0ce24aae0943    39156-5
# 3      5114a5b4-64b8-47b2-82a6-0ce24aae0943     8480-6
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79674 entries, 0 to 79673
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE         79674 non-null  object
#  1   PATIENT      79674 non-null  object
#  2   ENCOUNTER    76750 non-null  object
#  3   CODE         79674 non-null  object
#  4   DESCRIPTION  79674 non-null  object
#  5   VALUE        79219 non-null  object
#  6   UNITS        79219 non-null  object
# dtypes: object(7)
# memory usage: 4.3+ MB

# %%
print(data.isna().sum())
# Out:
# DATE              0
# PATIENT           0
# ENCOUNTER      2924
# CODE              0
# DESCRIPTION       0
# VALUE           455
# UNITS           455
# dtype: int64

# %%
print(data.duplicated().sum())
# Out:
# 2172

# %%
data = data.dropna()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 76295 entries, 0 to 79671
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE         76295 non-null  object
#  1   PATIENT      76295 non-null  object
#  2   ENCOUNTER    76295 non-null  object
#  3   CODE         76295 non-null  object
#  4   DESCRIPTION  76295 non-null  object
#  5   VALUE        76295 non-null  object
#  6   UNITS        76295 non-null  object
# dtypes: object(7)
# memory usage: 4.7+ MB

# %%
data.drop(["CODE", "ENCOUNTER"], axis=1, inplace=True)

# %%
data
# Out:
#              DATE                               PATIENT  \
# 0      2008-03-11  71949668-1c2e-43ae-ab0a-64654608defb
# 1      2008-03-11  71949668-1c2e-43ae-ab0a-64654608defb
# 2      2008-03-11  71949668-1c2e-43ae-ab0a-64654608defb
# 3      2008-03-11  71949668-1c2e-43ae-ab0a-64654608defb
# 4      2008-03-11  71949668-1c2e-43ae-ab0a-64654608defb
# ...           ...                                   ...
# 79667  2017-07-10  8b9de29c-34c9-405f-840c-71b5210cf9e1
# 79668  2017-07-10  8b9de29c-34c9-405f-840c-71b5210cf9e1
# 79669  2017-07-10  8b9de29c-34c9-405f-840c-71b5210cf9e1
# 79670  2017-07-10  8b9de29c-34c9-405f-840c-71b5210cf9e1
# 79671  2017-07-10  8b9de29c-34c9-405f-840c-71b5210cf9e1
#
#                                 DESCRIPTION   VALUE   UNITS
# 0                               Body Height  166.03      cm
# 1                               Body Weight   54.42      kg
# 2                           Body Mass Index   19.74   kg/m2
# ...

# %%
data['VALUE'] = pd.to_numeric(data['VALUE'], errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 76295 entries, 0 to 79671
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE         76295 non-null  object
#  1   PATIENT      76295 non-null  object
#  2   DESCRIPTION  76295 non-null  object
#  3   VALUE        75520 non-null  float64
#  4   UNITS        76295 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 5.5+ MB

# %%
data = data.dropna()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 75520 entries, 0 to 79671
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE         75520 non-null  object
#  1   PATIENT      75520 non-null  object
#  2   DESCRIPTION  75520 non-null  object
#  3   VALUE        75520 non-null  float64
#  4   UNITS        75520 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 3.5+ MB

# %%
data
# Out:
#              DATE                               PATIENT  \
# 0      2008-03-11  71949668-1c2e-43ae-ab0a-64654608defb
# 1      2008-03-11  71949668-1c2e-43ae-ab0a-64654608defb
# 2      2008-03-11  71949668-1c2e-43ae-ab0a-64654608defb
# 3      2008-03-11  71949668-1c2e-43ae-ab0a-64654608defb
# 4      2008-03-11  71949668-1c2e-43ae-ab0a-64654608defb
# ...           ...                                   ...
# 79667  2017-07-10  8b9de29c-34c9-405f-840c-71b5210cf9e1
# 79668  2017-07-10  8b9de29c-34c9-405f-840c-71b5210cf9e1
# 79669  2017-07-10  8b9de29c-34c9-405f-840c-71b5210cf9e1
# 79670  2017-07-10  8b9de29c-34c9-405f-840c-71b5210cf9e1
# 79671  2017-07-10  8b9de29c-34c9-405f-840c-71b5210cf9e1
#
#                                 DESCRIPTION   VALUE   UNITS
# 0                               Body Height  166.03      cm
# 1                               Body Weight   54.42      kg
# 2                           Body Mass Index   19.74   kg/m2
# ...

# %%
print(data.describe())
# Out:
#               VALUE
# count  75520.000000
# mean      76.712193
# std       58.693714
# min       -3.790000
# 25%       20.000000
# 50%       76.000000
# 75%      117.000000
# max      595.000000

# %%
data.to_csv('observations_LIMPIO.csv', index=False)

# %%
from google.colab import files
files.download('observations_LIMPIO.csv')

# %%
file_path = r"/content/drive/MyDrive/parkinsons_updrs.data.csv"
data = pd.read_csv(file_path)
data
# Out:
#       index  subject#  age  sex  test_time  motor_UPDRS  total_UPDRS  \
# 0         0         1   72    0     5.6431       28.199       34.398
# 1         1         1   72    0    12.6660       28.447       34.894
# 2         2         1   72    0    19.6810       28.695       35.389
# 3         3         1   72    0    25.6470       28.905       35.810
# 4         4         1   72    0    33.6420       29.187       36.375
# ...     ...       ...  ...  ...        ...          ...          ...
# 5870   5870        42   61    0   142.7900       22.485       33.485
# 5871   5871        42   61    0   149.8400       21.988       32.988
# 5872   5872        42   61    0   156.8200       21.495       32.495
# 5873   5873        42   61    0   163.7300       21.007       32.007
# 5874   5874        42   61    0   170.7300       20.513       31.513
#
#       Jitter(%)  Jitter(Abs)  Jitter:RAP  ...  Shimmer(dB)  Shimmer:APQ3  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5875 entries, 0 to 5874
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          5875 non-null   int64
#  1   subject#       5875 non-null   int64
#  2   age            5875 non-null   int64
#  3   sex            5875 non-null   int64
#  4   test_time      5875 non-null   float64
#  5   motor_UPDRS    5875 non-null   float64
#  6   total_UPDRS    5875 non-null   float64
#  7   Jitter(%)      5875 non-null   float64
#  8   Jitter(Abs)    5875 non-null   float64
#  9   Jitter:RAP     5875 non-null   float64
#  10  Jitter:PPQ5    5875 non-null   float64
#  11  Jitter:DDP     5875 non-null   float64
#  12  Shimmer        5875 non-null   float64
#  13  Shimmer(dB)    5875 non-null   float64
#  14  Shimmer:APQ3   5875 non-null   float64
#  15  Shimmer:APQ5   5875 non-null   float64
#  16  Shimmer:APQ11  5875 non-null   float64
# ...

# %%
print(data.isna().sum())
# Out:
# index            0
# subject#         0
# age              0
# sex              0
# test_time        0
# motor_UPDRS      0
# total_UPDRS      0
# Jitter(%)        0
# Jitter(Abs)      0
# Jitter:RAP       0
# Jitter:PPQ5      0
# Jitter:DDP       0
# Shimmer          0
# Shimmer(dB)      0
# Shimmer:APQ3     0
# Shimmer:APQ5     0
# Shimmer:APQ11    0
# Shimmer:DDA      0
# NHR              0
# HNR              0
# RPDE             0
# DFA              0
# PPE              0
# dtype: int64

# %%
print(data.duplicated().sum())
# Out:
# 0

# %%
data.to_csv('Parkinsons_updrs.data_LIMPIO.csv', index=False)

# %%
from google.colab import files
files.download('Parkinsons_updrs.data_LIMPIO.csv')
